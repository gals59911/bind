# %% [markdown]
# <a href="https://colab.research.google.com/github/gals59911/bind/blob/main/dpo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - square area: $s = (2 r)^2$
# - circle area: $c = \pi r^2$
# - $c/s = (\pi r^2) / (4 r^2) = \pi / 4$
# - $\pi = 4 * c/s$

# %% [markdown]
# ## Изображение для визуализации концепции
# ![Darts](https://raw.githubusercontent.com/coderefinery/jupyter/main/example/darts.svg)

# %%
# Импорт необходимых модулей
import random
import matplotlib.pyplot as plt

# Инициализация количества "бросков"
num_points = 1000

# Здесь мы "бросаем дротики" и подсчитываем  количество попаданий
points = []
hits = 0
for _ in range(num_points):
  x, y = random.random(), random.random()
  if x*x + y*y < 1.0:
          hits += 1
          points.append((x, y, "red"))
  else:
          points.append((x, y, "blue"))
# Распакуем точки в 3 списка
x, y, colors = zip(*points)
# Определяем размеры фигуры
fig, ax = plt.subplots()
fig.set_size_inches(6.0, 6.0)
# Рисуем результат
ax.scatter(x, y, c=colors)
# Считаем оценку
fraction = hits / num_points
4 * fraction
# Out:
# 3.236
